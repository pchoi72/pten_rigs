# %%
import pandas as pd
rigs = pd.read_csv('rigs.csv', names=['rig', 'availability', 'region', 'county', 'horsepower', 'class'])
rigs['date'] = pd.Timestamp('2020-02-09') ####### MUST CHANGE THIS
rigs = rigs[['date', 'rig', 'availability', 'region', 'county', 'horsepower', 'class']]
rigs
# Out:
#           date    rig availability              region    county  horsepower  \
# 0   2020-02-09    202    Available         South Texas  Victoria        1500
# 1   2020-02-09    204    Available          West Texas   Midland        1500
# 2   2020-02-09    207    Available          West Texas   Midland        1500
# 3   2020-02-09    209    Operating  East & North Texas   Bossier        1500
# 4   2020-02-09    210    Available  East & North Texas     Smith        1500
# ..         ...    ...          ...                 ...       ...         ...
# 211 2020-02-09  10003    Available              Canada       NaN        1300
# 212 2020-02-09  10014    Available              Canada       NaN        1300
# 213 2020-02-09  10015    Available              Canada       NaN        1300
# 214 2020-02-09  10016    Operating              Canada       NaN        1300
# 215 2020-02-09  10017    Available              Canada       NaN         750
#
#               class
# 0              APEX
# ...

# %%
rigs.to_csv('rigs_2020-02-09.csv', index=False) ###### MUST CHANGE THIS

# %%
temp1 = pd.read_csv('rigs_2020-02-08.csv')
temp2 = pd.read_csv('rigs_2020-02-09.csv')
a = temp1 == temp2
pd.set_option('display.max_rows', 300)
display(a)
# Out:
#       date   rig  availability  region  county  horsepower  class
# 0    False  True          True    True    True        True   True
# 1    False  True          True    True    True        True   True
# 2    False  True          True    True    True        True   True
# 3    False  True          True    True    True        True   True
# 4    False  True          True    True    True        True   True
# 5    False  True          True    True    True        True   True
# 6    False  True          True    True    True        True   True
# 7    False  True          True    True    True        True   True
# 8    False  True          True    True    True        True   True
# 9    False  True          True    True    True        True   True
# 10   False  True          True    True    True        True   True
# 11   False  True          True    True    True        True   True
# 12   False  True          True    True    True        True   True
# ...
